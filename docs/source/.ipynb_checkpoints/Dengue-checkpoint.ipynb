# %% [markdown]
# # Análise exploratória de casos de Dengue notificado pelo SUS
#
# Neste tutorial vamos explorar como começar a entender a descrição de casos do sis tema de notificação de agravos do SUS, o SINAN. Estes dados são bastante ricos e a [documentação](www.sgc.goias.gov.br/upload/arquivos/2013-08/dengue2.pdf) sobre o significado de cada uma das variáveis pode ser encontrada [aqui](www.sgc.goias.gov.br/upload/arquivos/2013-08/dengue2.pdf).

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Primeiro vamos começar pelo carregamento dos dados a partir do site do InfoDengue. Como o dado está no formato CSV, nós vamos utilizar a biblioteca pandas para carregar os dados diretamente da web, em um Dataframe.

# %%
casos = pd.read_csv('https://info.dengue.mat.br/dumps/Mosquito.Borne.Disease.tar.gz',compression='gzip',header=0, index_col=0)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Agora podemos selecionar apenas as linhas correspondetes à dengue, usando a variável *ID_AGRAVO* como filtro. Esta coluna contém o código da doença de acordo com a Classificação Internacional de Doenças (CID).

# %%
casos = casos[casos.ID_AGRAVO=='A90']
casos.head()
# Out:
#                            ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# Mosquito.Borne.Disease.csv
# 1.0                              A90  2015-09-17     37.0  2015.0       33.0
# 2.0                              A90  2015-05-15     19.0  2015.0       33.0
# 3.0                              A90  2015-08-14     32.0  2015.0       33.0
# 4.0                              A90  2015-08-18     33.0  2015.0       33.0
# 5.0                              A90  2015-08-18     33.0  2015.0       33.0
#
#                             ID_MUNICIP  ID_REGIONA  ID_UNIDADE  DT_SIN_PRI  \
# Mosquito.Borne.Disease.csv
# 1.0                           330455.0         NaN   2296608.0  2015-08-26
# 2.0                           330455.0         NaN   7722494.0  2015-05-10
# 3.0                           330455.0         NaN   2291266.0  2015-08-08
# 4.0                           330455.0         NaN   3134822.0  2015-06-19
# 5.0                           330455.0         NaN   3134822.0  2015-06-18
#
#                             SEM_PRI     ...     NU_LOTE_V  NU_LOTE_H  \
# Mosquito.Borne.Disease.csv              ...
# 1.0                            34.0     ...           NaN        NaN
# 2.0                            19.0     ...           NaN        NaN
# 3.0                            31.0     ...           NaN        NaN
# 4.0                            24.0     ...           NaN        NaN
# 5.0                            24.0     ...           NaN        NaN
#
#                            CS_FLXRET  FLXRECEBI  IDENT_MICR  MIGRADO_W  \
# Mosquito.Borne.Disease.csv
# 1.0                              1.0        NaN         4.0        NaN
# 2.0                              0.0        NaN         4.0        NaN
# 3.0                              1.0        NaN         4.0        NaN
# 4.0                              0.0        NaN         4.0        NaN
# 5.0                              1.0        NaN         4.0        NaN
#
#                             TP_SISTEMA   latitude  longitude  NM_DISEASE
# Mosquito.Borne.Disease.csv
# 1.0                                2.0 -22.925318 -43.388889      Dengue
# 2.0                                2.0 -22.872878 -43.425393      Dengue
# 3.0                                2.0 -22.826738 -43.329702      Dengue
# 4.0                                2.0 -22.879648 -43.339151      Dengue
# 5.0                                2.0 -22.814463 -43.380845      Dengue
#
# [5 rows x 55 columns]

# %% [markdown]
# Estes dados correspondem a todos os casos de dengue notificado ao SUS durante um período. Neste caso de 2015 a 2016. Para podermos tratar adequadamente estes dados para fins de visualização ou análise precisamos corrigir os tipos das colunas. Por exemplo vamos converter as datas.

# %%
casos.DT_NOTIFIC = pd.to_datetime(casos.DT_NOTIFIC)

# %% [markdown]
# Para poder organizar os dados temporalmente, é útil indexar a tabela por alguma variável temporal

# %%
casos = casos.set_index('DT_NOTIFIC')

# %% [markdown]
# Agora podemos plotar o número de casos por semana de dengue na cidade do Rio de Janeiro.

# %%
casos.ID_AGRAVO.resample('1W').count().plot(grid=True);

# %% [markdown]
# Suponhamos agora que desejamos visualizar em um mapa os casos que ocorreram, por exemplo entre janeiro e março de 2015

# %%
mapa  = folium.Map(location=[-22.914921, -43.194043])
casos_janeiro = casos.ix['2015-01-01':'2015-03-31']
popups = casos_janeiro.CS_SEXO.values
mapa.add_children(MarkerCluster(locations=casos_janeiro[['latitude','longitude']].values.tolist(), popups=popups))
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
